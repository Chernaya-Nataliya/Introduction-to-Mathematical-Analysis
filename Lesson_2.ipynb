# %% [markdown]
# ## Тема “Введение в математических анализ”
# ### Задача 1.
# Как относятся друг к другу множество и последовательность? (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т.д.)

# %% [markdown]
# Множество можно рассматривать как общее понятие, охватывающее определённый набор элементов, не обязательно упорядоченных. Последовательность, в свою очередь, является частным случаем множества, где элементы упорядочены по определённому правилу (индексации). То есть последовательность можно считать подмножеством множества, где каждый элемент имеет уникальный индекс, который отражает его позицию в порядке. Можно также сказать, что множество играет роль родителя, а последовательность — дочернего субъекта, который наследует свойства множества, но добавляет к ним порядок и, в большинстве случаев, направление (например, возрастающее или убывающее).

# %% [markdown]
# ### Задача 2
# Прочитать высказывания математической логики, построить их отрицания и установить
# истинность.
#
# + $\forall y \in [0;1]:sgn(y)=1$
# + $\forall n \in \mathbb {N} > 2 : \exists x, y, z \in \mathbb {N}: x^n = y^n + z^n$
# + $\forall x \in \mathbb {R} \exists X \in \mathbb {R} :X >x$
# + $\forall x \in \mathbb {C} \nexists y \in \mathbb {C} : x > y \parallel x < y$
# + $\forall y \in [0; \frac {\pi} {2}] \exists \epsilon> 0: \sin{y} < \sin{(y + \epsilon)}$
# + $\forall y \in [0; \pi) \exists \epsilon> 0: \cos{y} > \cos{(y + \epsilon)}$
# + $\exists x: x \notin \{\mathbb{N, Z, Q, R, C}\}$

# %% [markdown]
# Высказывание 1: $\forall y \in [0;1]: \text{sgn}(y) = 1$
#
# Отрицание:
# - Утверждение говорит, что для любого 𝑦 из интервала [0; 1] функция знака sgn(y) равна 1.
# - Чтобы найти отрицание, мы заменяем квантор всеобщности ∀ на квантор существования ∃ и меняем утверждение на противоположное:
# - Отрицание: «Существует такое y из интервала [0;1], что sgn(y) ≠ 1».
#
# Истинность:
# - Утверждение ложно, потому что на интервале [0;1] находится число y = 0, для которого которого sgn(0)=0, а не 1. Следовательно, существует y, для которого sgn(y) ≠ 1.

# %% [markdown]
# Высказывание 2: $\forall n \in \mathbb{N} > 2 : \exists x, y, z \in \mathbb{N}: x^n = y^n + z^n$
#
# Отрицание:
# - Это утверждение гласит, что для любого натурального числа n>2 существуют такие натуральные числа x,y,z, что x^n = y^n + z^n.
# - Отрицание заключается в том, что существует такое n (взятое из множества натуральных чисел больше 2), для которого никакие x,y,z из натуральных чисел не могут удовлетворять уравнению x^n = y^n + z^n.
#
# Истинность:
# - Утверждение ложно, поскольку теорема Ферма гласит, что для n>2 нет таких натуральных чисел x,y,z, которые удовлетворяли бы уравнению
# x^n = y^n + z^n. Это делает отрицание истинным, а исходное утверждение ложным.

# %% [markdown]
# Высказывание 3: $\forall x \in \mathbb{R} \exists X \in \mathbb{R} : X > x$
#
# Отрицание:
# - Утверждение гласит, что для любого действительного числа x существует такое действительное число X, которое больше x.
# - Отрицание: существует такое действительное число x, что для всех X выполняется X ≤ x.
#
# Истинность:
# - Утверждение истинно, так как для любого x всегда можно найти большее число X = x + 1. Поэтому отрицание будет ложным.

# %% [markdown]
# Высказывание 4: $\forall x \in \mathbb{C} \nexists y \in \mathbb{C} : x > y \parallel x < y$
#
# Отрицание:
# - Утверждение гласит, что для любого комплексного числа x не существует комплексного числа y, для которого можно было бы сказать, что
# x > y или x < y.
# - Отрицание: существует такое комплексное число x и такое комплексное число y, что x > y или x < y.
#
# Истинность:
# - Утверждение истинно, так как в комплексных числах нет строгого порядка, который позволял бы сравнивать их как больше или меньше.

# %% [markdown]
# Высказывание 5: $\forall y \in [0; \frac{\pi}{2}] \exists \epsilon > 0 : \sin{y} < \sin{(y + \epsilon)}$
#
# Отрицание:
# - Утверждение гласит, что для любого y из интервала [0; \frac{\pi}{2}] существует такое ϵ > 0, что sin(y) < sin(y+ϵ).
# - Отрицание: существует такое y из интервала [0; \frac{\pi}{2}], что для всех ϵ > 0 выполняется sin(y) ≥ sin(y+ϵ).
#
# Истинность:
# - Утверждение ложно, поскольку, например, при y = $\frac{\pi}{2}$ синус достигает максимума, и любое увеличение y уменьшает значение синуса: sin(y+ϵ) < sin(y). Следовательно, отрицание истинно.

# %% [markdown]
# Высказывание 6: $\forall y \in [0; \pi) \exists \epsilon > 0 : \cos{y} > \cos{(y + \epsilon)}$
#
# Отрицание:
# - Утверждение гласит, что для любого y из интервала [0;π) существует такое ϵ>0, что cos(y) > cos(y+ϵ).
# - Отрицание: существует такое y из интервала [0;π), что для всех ϵ>0 выполняется cos(y) ≤ cos(y+ϵ).
#
# Истинность:
# - Утверждение ложно, поскольку при y=0 косинус достигает максимума, и любое увеличение y уменьшает значение косинуса: cos(y+ϵ) < cos(y). Поэтому отрицание будет истинным.

# %% [markdown]
# Высказывание 7: $\exists x: x \notin {\mathbb{N, Z, Q, R, C}}$
#
# Отрицание:
# - Утверждение гласит, что существует такое x, которое не принадлежит множествам натуральных, целых, рациональных, действительных или комплексных чисел.
# - Отрицание: все x принадлежат хотя бы одному из этих множеств.
#
# Истинность:
# - Утверждение истинно, так как существуют математические объекты (например, кватернионы H или другие числа), которые не принадлежат ни одному из этих множеств. Следовательно, отрицание ложно.

# %% [markdown]
# ## Тема “Множество”
# ### Задача 1.
# Даны три множества a, b и с. Необходимо выполнить все изученные виды бинарных операций
# над всеми комбинациями множеств.

# %% [markdown]
# Выполним все бинарные операции над множествами a, b и c:
#
# Пусть множества:
#
# $a = {1, 2, 3}$
# $b = {2, 3, 4}$
# $c = {3, 4, 5}$
#
# Для трех множеств a, b и c можно выполнить следующие бинарные операции:
#
# 1. Объединение ($\cup$):
#
# $a \cup b = {1, 2, 3, 4}$
# $a \cup c = {1, 2, 3, 4, 5}$
# $b \cup c = {2, 3, 4, 5}$
#
# 2. Пересечение ($\cap$):
#
# $a \cap b = {2, 3}$
# $a \cap c = {3}$
# $b \cap c = {3, 4}$
#
# 3. Разность ($\setminus$):
#
# $a \setminus b = {1}$
# $a \setminus c = {1, 2}$
# $b \setminus a = {4}$
# $b \setminus c = {2}$
# $c \setminus a = {4, 5}$
# $c \setminus b = {5}$
#
# 4. Симметрическая разность ($\Delta$):
#
# $a \Delta b = {1, 4}$
# $a \Delta c = {1, 2, 4, 5}$
# $b \Delta c = {2, 5}$

# %% [markdown]
# ### Задача 2
# *Выполнить задание 1 на языке Python

# %%
a = {1, 2, 3}
b = {2, 3, 4}
c = {3, 4, 5}

# Объединение
a_union_b = a | b
a_union_c = a | c
b_union_c = b | c
print(f"a ∪ b = {a_union_b}")
print(f"a ∪ c = {a_union_c}")
print(f"b ∪ c = {b_union_c}")
# Out:
# a ∪ b = {1, 2, 3, 4}
# a ∪ c = {1, 2, 3, 4, 5}
# b ∪ c = {2, 3, 4, 5}

# %%
# Пересечение
a_intersection_b = a & b
a_intersection_c = a & c
b_intersection_c = b & c
print(f"a ∩ b = {a_intersection_b}")
print(f"a ∩ c = {a_intersection_c}")
print(f"b ∩ c = {b_intersection_c}")
# Out:
# a ∩ b = {2, 3}
# a ∩ c = {3}
# b ∩ c = {3, 4}

# %%
# Разность
a_diff_b = a - b
a_diff_c = a - c
b_diff_a = b - a
b_diff_c = b - c
c_diff_a = c - a
c_diff_b = c - b
print(f"a \\ b = {a_diff_b}")
print(f"a \\ c = {a_diff_c}")
print(f"b \\ a = {b_diff_a}")
print(f"b \\ c = {b_diff_c}")
print(f"c \\ a = {c_diff_a}")
print(f"c \\ b = {c_diff_b}")
# Out:
# a \ b = {1}
# a \ c = {1, 2}
# b \ a = {4}
# b \ c = {2}
# c \ a = {4, 5}
# c \ b = {5}

# %%
# Симметрическая разность
a_symdiff_b = a ^ b
a_symdiff_c = a ^ c
b_symdiff_c = b ^ c
print(f"a Δ b = {a_symdiff_b}")
print(f"a Δ c = {a_symdiff_c}")
print(f"b Δ c = {b_symdiff_c}")
# Out:
# a Δ b = {1, 4}
# a Δ c = {1, 2, 4, 5}
# b Δ c = {2, 5}

# %% [markdown]
# ## Тема 3 “Последовательность”
# ### Задача 1.
# Даны 4 последовательности. Необходимо:
# a. исследовать их на монотонность;
# b. исследовать на ограниченность;
# c. найти пятый по счету член.
#
# + $\{a_n\}^\infty_{n=1}=2^n -n$
# + $\{b_n\}^\infty_{n=2} = \frac {1} {1 -n}$
# + $\{c_n\}^\infty_{n=1} = -1^n + \sqrt{2n}$
# + $\{d_n\}^\infty_{n=1}= (-1)^{2n} + \frac{1}{n^2}$

# %% [markdown]
# Исследуем последовательности на монотонность, ограниченность и найдем пятый член.
#
# 1. Последовательность ${a_n}^\infty_{n=1} = 2^n - n$
# - Монотонность: Последовательность возрастает, так как прирост $2^n$ больше, чем убыль $n$.
# - Ограниченность: Последовательность не ограничена сверху.
# Пятый член: $a_5 = 2^5 - 5 = 27$.
#
# 2. Последовательность ${b_n}^\infty_{n=2} = \frac{1}{1-n}$
# - Монотонность: Убывает.
# - Ограниченность: Ограничена сверху (при $n = 2$).
# - Пятый член: $b_5 = \frac{1}{1-5} = -\frac{1}{4}$.
#
# 3. Последовательность${c_n}^\infty_{n=1} = -1^n + \sqrt{2n}$
# - Монотонность: Чередуется знаки (зависит от $n$), но растет за счет $\sqrt{2n}$.
# - Ограниченность: Не ограничена снизу или сверху.
# - Пятый член: $c_5 = (-1)^5 + \sqrt{10} \approx 1 + 3.16 = 4.16$.
#
# 4. Последовательность ${d_n}^\infty_{n=1} = (-1)^{2n} + \frac{1}{n^2}$
# - Монотонность: Убывает к 1, так как $\frac{1}{n^2}$ уменьшается.
# - Ограниченность: Ограничена снизу 1.
# - Пятый член: $d_5 = 1 + \frac{1}{25} = 1.04$.

# %% [markdown]
# ### Задача 2
# Найти 12-й член заданной неявно последовательности
# $a_1 =128, a_{n+1} - a_n =6$

# %% [markdown]
# Используем формулу для нахождения $a_{12}$ в арифметической прогрессии:
#
# $a_12 = a_1 + 11\times 6 = 128 + 66 = 194$

# %%
a1 = 128
for _ in range(11):
    a1 += 6
print(a1)
# Out:
# 194

# %% [markdown]
# ### Задача 3
# *На языке Python предложить алгоритм вычисляющий численно предел с точностью
# $\epsilon = 10^7$
# $\lim\limits_{n \to +\infty} \frac{n}{\sqrt[n]{n!}}$

# %%
# Логарифм факториала: Для вычисления факториала используется логарифм суммы, чтобы избежать переполнения.
# Погрешность: Проверяем разницу между текущим и предыдущим значением, чтобы достигнуть заданной точности $\epsilon$.

import math

def calculate_limit(epsilon=1e-7):
    prev_value = 0
    n = 1
    log_fact = 0  # Логарифм факториала
    while True:
        log_fact += math.log(n)
        n_fact_root = math.exp(log_fact / n)
        current_value = n / n_fact_root
        if abs(current_value - prev_value) < epsilon:
            break
        prev_value = current_value
        n += 1
    return current_value, n

limit, n = calculate_limit()
print(f"Предел приблизительно равен {limit}, рассчитанный при n = {n}")
# Out:
# Предел приблизительно равен 2.7169884237242354, рассчитанный при n = 11779

# %% [markdown]
# ### Задача 4
# *Предложить оптимизацию алгоритма, полученного в задании 3, ускоряющую его сходимость

# %% [markdown]
# Для оптимизации алгоритма, ускоряющего его сходимость, можно использовать метод Стерлинга для аппроксимации факториала:
#
# $n! \approx \sqrt{2\pi n} \left(\frac{n}{e}\right)^n$

# %%
import mpmath

def calculate_limit_optimized(epsilon=1e-7):
    mpmath.mp.dps = 50  # количество знаков после запятой для расчетов. Значение в 50 знаков выбрано как "с запасом", чтобы это не повлияло на точность итоговых расчетов.
    prev_value = mpmath.mpf('0')
    n = 1
    while True:
        n_fact_approx = mpmath.sqrt(2 * mpmath.pi * n) * (n / mpmath.e)**n
        n_fact_root = n_fact_approx**(1/n)
        current_value = n / n_fact_root
        if abs(current_value - prev_value) < epsilon:
            break
        prev_value = current_value
        n += 1
    return current_value, n

limit, n = calculate_limit_optimized()
print(f"Оптимизированный предел приблизительно равен {limit}, рассчитанный при n = {n}")
# Out:
# Оптимизированный предел приблизительно равен 2.7169884253561045045489272623003308236860044841308, рассчитанный при n = 11779
